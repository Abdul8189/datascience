# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdul8189/datascience/blob/main/Decision_tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from mlxtend.plotting import plot_decision_regions

# %%
dataset=pd.read_csv('ads.csv')

# %%
dataset.head(3)
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0

# %%
x= dataset.iloc[:,:-1]

# %%
y=dataset['Purchased']

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.preprocessing import  StandardScaler

# %%
sc=StandardScaler()

# %%
sc.fit(x)
# Out:
# StandardScaler()

# %%
x=pd.DataFrame(sc.fit_transform(x),columns=x.columns)

# %%
x
# Out:
#           Age  EstimatedSalary
# 0   -1.781797        -1.490046
# 1   -0.253587        -1.460681
# 2   -1.113206        -0.785290
# 3   -1.017692        -0.374182
# 4   -1.781797         0.183751
# ..        ...              ...
# 395  0.797057        -0.844019
# 396  1.274623        -1.372587
# 397  1.179110        -1.460681
# 398 -0.158074        -1.078938
# 399  1.083596        -0.990844
#
# [400 rows x 2 columns]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dc= DecisionTreeClassifier()

# %%
dc.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
dc.score(x_test,y_test)*100
# Out:
# 83.75

# %%
from sklearn.tree import  plot_tree

# %%
plt.figure(figsize=(10,5))
plot_tree(dc)
plt.show()

# %%
dataset.head(3)
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0

# %%
 sns.scatterplot(x='Age',y='EstimatedSalary',data=dataset,hue='Purchased')
 plt.show()

# %%
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=dc)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# <Axes: >
